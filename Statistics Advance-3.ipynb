# %%
#Q1

# %%
# Estimation statistics is a branch of statistics concerned with estimating unknown parameters of a population based on information obtained from a sample. Estimation involves using sample data to make inferences about population parameters, such as the population mean, population proportion, population variance, etc.

# Point Estimate:
# A point estimate is a single value calculated from sample data that serves as the best guess or "point" estimate of the population parameter of interest. It provides a single numerical value as an estimate of the unknown population parameter. Point estimates are typically obtained by calculating sample statistics, such as the sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ), sample proportion (
# 𝑝
# p), or sample standard deviation (
# 𝑠
# s).

# For example, if we want to estimate the population mean (
# 𝜇
# μ) based on a sample of data, the sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) would be the point estimate of the population mean.

# Interval Estimate:
# An interval estimate provides a range of values within which the true population parameter is believed to lie, along with a level of confidence associated with the estimate. It recognizes the uncertainty inherent in estimation and provides a range of plausible values for the population parameter. Interval estimates are constructed by specifying a point estimate and a margin of error around that point estimate.

# The most common type of interval estimate is a confidence interval, which provides a range of values around the point estimate that is likely to contain the true population parameter with a specified level of confidence (e.g., 95% confidence interval, 99% confidence interval).

# For example, if we calculate a 95% confidence interval for the population mean (
# 𝜇
# μ), we would obtain a range of values within which we are 95% confident that the true population mean lies.

# Importance of Estimation Statistics:
# Estimation statistics allows researchers and analysts to make inferences about population parameters based on sample data, even when the entire population cannot be observed or measured.
# It provides a framework for quantifying uncertainty and making informed decisions in the presence of variability.
# Estimation techniques are widely used in research, business, government, and other fields to estimate population parameters, make predictions, and guide decision-making processes.
# In summary, estimation statistics plays a crucial role in statistical analysis and inference by providing estimates of population parameters and assessing the uncertainty associated with those estimates. Point estimates give a single best guess of the parameter, while interval estimates provide a range of plausible values along with a level of confidence.

# %%
#Q2

# %%
def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    """
    Function to estimate the population mean using sample mean and standard deviation.
    
    Parameters:
    sample_mean (float): The sample mean.
    sample_std_dev (float): The sample standard deviation.
    sample_size (int): The size of the sample.
    
    Returns:
    float: Estimated population mean.
    """
    import math
    
    # Calculate the standard error of the mean (SEM)
    standard_error = sample_std_dev / math.sqrt(sample_size)
    
    # Estimate the population mean using the sample mean and SEM
    population_mean = sample_mean
    
    return population_mean

# Example usage:
sample_mean = 50
sample_std_dev = 10
sample_size = 100

estimated_mean = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
print("Estimated population mean:", estimated_mean)
# Out:
# Estimated population mean: 50

# %%
#Q3

# %%
# Hypothesis testing is a statistical method used to make inferences about population parameters based on sample data. It involves formulating hypotheses about the population parameters and using sample data to assess the evidence for or against these hypotheses. Hypothesis testing allows researchers to draw conclusions and make decisions based on empirical evidence.

# Process of Hypothesis Testing:
# Formulate Hypotheses:

# The first step in hypothesis testing is to formulate null and alternative hypotheses. The null hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ) represents the status quo or default assumption, while the alternative hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#   or 
# 𝐻
# 𝑎
# H 
# a
# ​
#  ) represents the researcher's claim or the hypothesis of interest.
# Select Significance Level:

# The significance level (
# 𝛼
# α) is the threshold for determining statistical significance. It represents the probability of rejecting the null hypothesis when it is actually true. Commonly used significance levels include 0.05, 0.01, and 0.10.
# Collect and Analyze Data:

# Data is collected from a sample, and sample statistics are calculated to estimate population parameters. The sample data is then used to perform statistical tests to evaluate the hypotheses.
# Perform Statistical Test:

# A statistical test is selected based on the nature of the data and the hypotheses being tested. Common statistical tests include t-tests, chi-square tests, ANOVA, etc. The test statistic is calculated from the sample data and compared to a critical value or p-value to determine whether the null hypothesis should be rejected.
# Draw Conclusions:

# Based on the results of the statistical test, conclusions are drawn regarding the null hypothesis. If the p-value is less than the significance level (
# 𝛼
# α), the null hypothesis is rejected in favor of the alternative hypothesis. Otherwise, if the p-value is greater than or equal to 
# 𝛼
# α, the null hypothesis is not rejected.
# Importance of Hypothesis Testing:
# Inference Making: Hypothesis testing provides a systematic framework for making inferences about population parameters based on sample data. It allows researchers to draw conclusions and make decisions based on empirical evidence.

# Scientific Research: In scientific research, hypothesis testing is used to evaluate theories, test hypotheses, and draw conclusions about the relationships between variables. It helps researchers assess the validity of their hypotheses and theories.

# Decision Making: In business, government, and other fields, hypothesis testing is used to inform decision-making processes. For example, it can be used to evaluate the effectiveness of marketing campaigns, assess the impact of policy changes, or compare the performance of different products or treatments.

# Quality Control: In manufacturing and quality control, hypothesis testing is used to assess the quality of products, detect defects or anomalies, and make decisions about process improvements. It helps ensure that products meet quality standards and specifications.

# Statistical Inference: Hypothesis testing is a fundamental tool in statistical inference, allowing researchers to draw conclusions about populations based on sample data. It provides a structured approach to evaluating evidence and assessing the strength of relationships between variables.

# Overall, hypothesis testing is a critical component of the scientific method and statistical analysis, providing a systematic approach to making inferences and drawing conclusions based on empirical evidence. It is used across various fields to test theories, inform decision-making processes, and advance knowledge and understanding.

# %%
#Q5

# %%
# Sure, here is a hypothesis statement that addresses the comparison of the average weight of male and female college students:

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ): The average weight of male college students is equal to or less than the average weight of female college students.
# 𝐻
# 0
# :
# 𝜇
# male
# ≤
# 𝜇
# female
# H 
# 0
# ​
#  :μ 
# male
# ​
#  ≤μ 
# female
# ​
 

# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#  ): The average weight of male college students is greater than the average weight of female college students.
# 𝐻
# 1
# :
# 𝜇
# male
# >
# 𝜇
# female
# H 
# 1
# ​
#  :μ 
# male
# ​
#  >μ 
# female
# ​
 

# In this hypothesis:

# 𝜇
# male
# μ 
# male
# ​
#   represents the population mean weight of male college students.
# 𝜇
# female
# μ 
# female
# ​
#   represents the population mean weight of female college students.
# We are testing whether the average weight of male college students is greater than the average weight of female college students. The null hypothesis assumes that there is no difference or that the average weight of male students is equal to or less than the average weight of female students. The alternative hypothesis suggests that the average weight of male students is greater than the average weight of female students.

# %%
#Q6

# %%
# In hypothesis testing, the null hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ) and the alternative hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#   or 
# 𝐻
# 𝑎
# H 
# a
# ​
#  ) are statements about the population parameter(s) being tested. They represent competing explanations or claims about the population and are mutually exclusive.

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ):
# The null hypothesis is the default assumption or the status quo.
# It represents the hypothesis of no effect, no difference, or no relationship.
# It is typically denoted as 
# 𝐻
# 0
# H 
# 0
# ​
#   and is what the researcher aims to test against.
# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#   or 
# 𝐻
# 𝑎
# H 
# a
# ​
#  ):
# The alternative hypothesis is the statement that contradicts the null hypothesis.
# It represents the hypothesis of interest, the claim being made, or the effect being investigated.
# It is denoted as 
# 𝐻
# 1
# H 
# 1
# ​
#   or 
# 𝐻
# 𝑎
# H 
# a
# ​
#   and is what the researcher seeks evidence to support.
# Examples of Null and Alternative Hypotheses:
# Example: Coin Toss:

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ): The coin is fair, and the probability of getting heads is 0.5.
# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#  ): The coin is biased, and the probability of getting heads is not equal to 0.5.
# Example: Drug Efficacy:

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ): The new drug has no effect on reducing blood pressure.
# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#  ): The new drug is effective in reducing blood pressure.
# Example: Gender and Salary:

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ): There is no difference in the average salary between male and female employees.
# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#  ): The average salary of male employees is greater than the average salary of female employees.
# Example: Education and Income:

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ): There is no association between education level and income.
# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#  ): There is a positive association between education level and income.
# Example: Website Conversion Rates:

# Null Hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ): The new website design does not lead to an increase in conversion rates.
# Alternative Hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#  ): The new website design leads to a higher conversion rate compared to the old design.
# In each example, the null hypothesis represents the absence of an effect or a relationship, while the alternative hypothesis represents the presence of an effect or a relationship that the researcher is interested in investigating. The goal of hypothesis testing is to gather evidence to either reject or fail to reject the null hypothesis based on the observed data.

# %%
#Q7

# %%
# Hypothesis testing is a systematic process used to make inferences about population parameters based on sample data. The following are the general steps involved in hypothesis testing:

# Formulate Hypotheses:

# State the null hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ) and the alternative hypothesis (
# 𝐻
# 1
# H 
# 1
# ​
#   or 
# 𝐻
# 𝑎
# H 
# a
# ​
#  ). The null hypothesis represents the status quo or the default assumption, while the alternative hypothesis represents the researcher's claim or the hypothesis of interest.
# Select Significance Level (
# 𝛼
# α):

# Determine the significance level (
# 𝛼
# α), which represents the threshold for determining statistical significance. Commonly used significance levels include 0.05, 0.01, and 0.10.
# Choose Statistical Test:

# Select an appropriate statistical test based on the nature of the data and the hypotheses being tested. Common statistical tests include t-tests, chi-square tests, ANOVA, etc.
# Collect and Analyze Data:

# Collect data from a sample and calculate sample statistics, such as the sample mean, sample proportion, or sample standard deviation.
# Calculate Test Statistic:

# Calculate the test statistic using the sample data. The test statistic depends on the chosen statistical test and measures the strength of the evidence against the null hypothesis.
# Determine Critical Value or P-value:

# Determine the critical value or p-value associated with the test statistic. The critical value represents the cutoff point beyond which the null hypothesis is rejected, while the p-value represents the probability of obtaining the observed result (or more extreme) under the null hypothesis.
# Make Decision:

# Compare the test statistic to the critical value or p-value to determine whether to reject the null hypothesis.
# If the test statistic falls in the rejection region (beyond the critical value) or if the p-value is less than the significance level (
# 𝛼
# α), reject the null hypothesis in favor of the alternative hypothesis.
# If the test statistic falls within the acceptance region (below the critical value) or if the p-value is greater than or equal to 
# 𝛼
# α, fail to reject the null hypothesis.
# Draw Conclusion:

# Based on the decision made in step 7, draw a conclusion about the null hypothesis. If the null hypothesis is rejected, provide evidence in support of the alternative hypothesis. If the null hypothesis is not rejected, conclude that there is insufficient evidence to support the alternative hypothesis.
# Interpret Results:

# Interpret the results of the hypothesis test in the context of the research question or problem being investigated. Discuss the implications of the findings and any further steps that may be needed.
# By following these steps, researchers can systematically evaluate hypotheses, make informed decisions, and draw valid conclusions based on empirical evidence

# %%
#Q8

# %%
# The p-value, or probability value, is a measure of the strength of evidence against the null hypothesis (
# 𝐻
# 0
# H 
# 0
# ​
#  ) in hypothesis testing. It represents the probability of observing a test statistic as extreme as, or more extreme than, the one calculated from the sample data, assuming that the null hypothesis is true. In other words, the p-value quantifies the likelihood of obtaining the observed result under the assumption that the null hypothesis is true.

# Significance of p-value in Hypothesis Testing:
# Decision Making:

# The p-value provides a basis for decision-making in hypothesis testing. If the p-value is less than or equal to the significance level (
# 𝛼
# α), typically 0.05, the null hypothesis is rejected in favor of the alternative hypothesis. If the p-value is greater than 
# 𝛼
# α, the null hypothesis is not rejected.
# Strength of Evidence:

# A smaller p-value indicates stronger evidence against the null hypothesis. For example, a p-value of 0.01 provides stronger evidence against the null hypothesis than a p-value of 0.05. Therefore, researchers can assess the strength of evidence based on the magnitude of the p-value.
# Interpretation of Results:

# The p-value helps researchers interpret the results of hypothesis tests. A low p-value suggests that the observed data are unlikely to occur under the null hypothesis, providing support for the alternative hypothesis. A high p-value indicates that the observed data are consistent with the null hypothesis, suggesting that there is insufficient evidence to reject it.
# Comparisons Across Studies:

# p-values allow for comparisons across different studies or experiments. Researchers can assess the significance of findings and evaluate the reproducibility of results by comparing the p-values obtained from different studies.
# Adjusting for Multiple Comparisons:

# In situations where multiple hypothesis tests are conducted simultaneously (e.g., testing multiple variables or conducting multiple comparisons), p-values can be adjusted to account for the increased likelihood of Type I errors (false positives). Methods such as the Bonferroni correction or false discovery rate (FDR) control help control the overall Type I error rate when conducting multiple tests.
# In summary, the p-value plays a crucial role in hypothesis testing by quantifying the strength of evidence against the null hypothesis and guiding decision-making. It provides a standardized measure that allows researchers to assess the significance of findings, interpret results, and draw valid conclusions based on empirical evidence.

# %%
#Q9

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Define the range of x values
x = np.linspace(-4, 4, 1000)

# Define the degrees of freedom
df = 10

# Calculate the probability density function (PDF) for the Student's t-distribution
pdf = t.pdf(x, df)

# Plot the PDF
plt.figure(figsize=(8, 6))
plt.plot(x, pdf, color='blue', label=f'Student\'s t-distribution (df={df})')
plt.title('Student\'s t-distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Q10

# %%
import numpy as np
from scipy.stats import t

def two_sample_t_test(sample1, sample2):
    """
    Perform two-sample t-test for independent samples.
    
    Parameters:
    sample1 (array-like): First sample data.
    sample2 (array-like): Second sample data.
    
    Returns:
    float: t-statistic
    float: p-value
    """
    # Calculate sample sizes
    n1 = len(sample1)
    n2 = len(sample2)
    
    # Calculate means and variances of the samples
    mean1 = np.mean(sample1)
    mean2 = np.mean(sample2)
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)
    
    # Calculate pooled standard deviation
    pooled_std_dev = np.sqrt((var1 + var2) / 2)
    
    # Calculate t-statistic
    t_statistic = (mean1 - mean2) / (pooled_std_dev * np.sqrt(1/n1 + 1/n2))
    
    # Calculate degrees of freedom
    degrees_of_freedom = n1 + n2 - 2
    
    # Calculate p-value
    p_value = 2 * (1 - t.cdf(abs(t_statistic), df=degrees_of_freedom))
    
    return t_statistic, p_value

# Example usage:
sample1 = np.random.normal(loc=50, scale=10, size=30)  # First random sample
sample2 = np.random.normal(loc=55, scale=10, size=30)  # Second random sample

t_statistic, p_value = two_sample_t_test(sample1, sample2)
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -1.3900962699953614
# p-value: 0.16981176033924883
